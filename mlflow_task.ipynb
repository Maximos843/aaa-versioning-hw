# %% [markdown]
# В этой работе будем иследовать одну из популярнейших рекомендательных моделей - **Latent Factor Model** - https://arxiv.org/pdf/1912.04754.
#
# Перед выполнением задания нужно убедиться, что прогоняется бейзлайн. Для этого:
# 1) Скачайте  файлы - **node2name.json** и **clickstream.parque** с необходимыми данными
# 2) Положите в репозиторий ноутбука и запустите код
#
# В этой работе вам нужно:
# 1) перебрать параметры модели - edim,batch_size, lr, epoch , num_negatives -   (по **1 балу - 5 балов**)
# 2) Тип OPTIMIZER_NAME - (**4 бала за 5 оптимизаторов**)
# 3) На основе имеющихся данных собрать лучшую модель (по **precision@30**) и рассчитать ее метрики (**4 бала**)
# 4) Попробовать другие модели (например  als - https://benfred.github.io/implicit/ , gru4rec, sasrec  ) - за sasrec на хорошем уровне сразу **10 балов**. За другие модели по **3 бала**
# 5) По окончанию работы в mlflow настроить графики для сравнения моделей. Можно проявить фантазию, но обязательно должно быть сравнение с бейзлайном (данный ноутбук) против других моделей
# 6) В mlflow залогировать последнюю версию ноутбука - необходимое условия. Либо в github, но тогда прикрепить ссылку в [mlflow](http://84.201.128.89:90/) . Эксперимент в формате - **homework-\<name\>**
# 7) Доп балы (**20 баллов**) тому у кого будет наибольший скор на тесте. Но ваш ноутбук должен прогонятся и быть вопроизводимым.
#
# Суммарно за работу **20 балов**

# %%
# !pip install optuna
# !pip install mlflow
# !pip install implicit

# %%
import json
import random
import mlflow
import os
import torch
import optuna
import pandas as pd
import numpy as np
import implicit
from scipy.sparse import csr_matrix
from torch import nn
from tqdm.auto import tqdm
from torch.utils.data import Dataset, DataLoader

# %%
SEED = 42

def set_seed():
    random.seed(SEED)
    np.random.seed(SEED)
    torch.manual_seed(SEED)
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = True

    os.environ['PYTHONHASHSEED'] = str(SEED)
    os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
    os.environ['CUDA_VISIBLE_DEVICES']= '1'


set_seed()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Prepare Data

# %%
with open('/content/drive/MyDrive/Avito_mlflow/node2name.json', 'r') as f:
    node2name = json.load(f)

node2name = {int(k):v for k,v in node2name.items()}

# %%
df = pd.read_parquet('/content/drive/MyDrive/Avito_mlflow/clickstream.parque')
df = df.head(100_000)
df.head()
# Out:
#    cookie_id          event_date  node_id
# 0   15157399 2024-02-21 11:20:01  1047840
# 1   15157399 2024-03-05 10:24:54  1047561
# 2   15157399 2024-03-05 10:28:55  1047561
# 3   15157399 2024-04-13 11:22:25  1047835
# 4   15157399 2024-04-13 11:22:45  1047835

# %%
df['is_train'] = df['event_date']< df['event_date'].max() - pd.Timedelta('2 day')
df['names'] = df['node_id'].map(node2name)

# %%
train_cooks = df[df['is_train']]['cookie_id'].unique()
train_items = df[df['is_train']]['node_id'].unique()


df = df[(df['cookie_id'].isin(train_cooks)) & (df['node_id'].isin(train_items))]

# %%
user_indes, index2user_id = pd.factorize(df['cookie_id'])
df['user_index'] = user_indes

node_indes, index2node = pd.factorize(df['node_id'])
df['node_index'] = node_indes

# %%
df['node_index'].max()
# Out:
# 2175

# %%
df_train, df_test = df[df['is_train']], df[~df['is_train']]
df_train = df_train.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)


df_train.shape, df_test.shape
# Out:
# ((96611, 7), (3333, 7))

# %% [markdown]
# # Define LatentFactorModel

# %%
class RecDataset(Dataset):
    def __init__(self, users, items, item_per_users):
        self.users = users
        self.items = items
        self.item_per_users=item_per_users

    def __len__(self):
        return len(self.users)

    def __getitem__(self, i):
        user = self.users[i]
        return torch.tensor(user), torch.tensor(self.items[i]), self.item_per_users[user]


class LatentFactorModel(nn.Module):
    def __init__(self, edim, user_indexes, node_indexes):
        super(LatentFactorModel, self).__init__()
        self.edim = edim
        self.users = nn.Embedding(max(user_indexes) + 1, edim)
        self.items = nn.Embedding(max(node_indexes) + 1, edim)

    def forward(self, users, items):
        user_embedings = self.users(users).reshape(-1, self.edim )
        item_embedings = self.items(items)
        res = torch.einsum('be,bne->bn', user_embedings, item_embedings)
        return res

    def pred_top_k(self, users, K=10):
        user_embedings = self.users(users).reshape(-1, self.edim )
        item_embedings = self.items.weight
        res = torch.einsum('ue,ie->ui', user_embedings, item_embedings)
        return torch.topk(res, K, dim=1)




def collate_fn(batch, num_negatives, num_items):
    users, target_items, users_negatives = [],[], []
    for triplets in batch:
        user, target_item, seen_item = triplets

        users.append(user)
        target_items.append(target_item)
        user_negatives = []

        while len(user_negatives)< num_negatives:
            candidate = random.randint(0, num_items)
            if candidate not in seen_item:
                user_negatives.append(candidate)

        users_negatives.append(user_negatives)


    positive = torch.ones(len(batch), 1)
    negatives = torch.zeros(len(batch), num_negatives)
    labels = torch.hstack([positive, negatives])
    items = torch.hstack([torch.tensor(target_items).reshape(-1, 1), torch.tensor(users_negatives)])
    return torch.hstack(users), items, labels

# %%
user2seen = df_train.groupby('user_index')['node_index'].agg(lambda x: list(set(x)))

# %% [markdown]
# # Baseline

# %%
train_dataset = RecDataset(df_train['user_index'].values, df_train['node_index'], user2seen)
dataloader = DataLoader(train_dataset, shuffle=True,num_workers=0, batch_size=50_000,collate_fn=lambda x: collate_fn(x, NUM_NEGATIVES, max(df['node_index'].values)))

# %%
BATCH_SIZE = 50_000
NUM_NEGATIVES = 5
EDIM = 128
EPOCH = 10
OPTIMIZER_NAME = 'Adam'
LR = 1

model = LatentFactorModel(EDIM, user_indes, node_indes)
optimizer = torch.optim.Adam(model.parameters(), LR)

bar = tqdm(total = EPOCH )

# %%
for i in range(EPOCH):
    bar_loader = tqdm(total = len(dataloader),)
    losses = []
    for i in dataloader:
        users, items, labels = i
        optimizer.zero_grad()
        logits = model(users, items)
        loss = torch.nn.functional.binary_cross_entropy_with_logits(
            logits, labels
        )
        loss.backward()
        optimizer.step()
        bar_loader.update(1)
        bar_loader.set_description(f'batch loss - {loss.item()}')
        losses.append(loss.item())

    bar.update(1)
    bar.set_description(f'epoch loss - {sum(losses)/len(losses)}')

# %%
hitrate, precision = calculate_metrics(model)
hitrate, precision
# Out:
# (0.7151424287856072, 0.04252873563218391)

# %%
with mlflow.start_run(run_name='baseline'):
        mlflow.log_metrics(
            {
                'hitrate-30': hitrate,
                'precision-30': precision,
            }
        )
        mlflow.log_params(
            {
                'BATCH_SIZE': BATCH_SIZE,
                'EPOCH': EPOCH,
                'NUM_NEGATIVES': NUM_NEGATIVES,
                'EDIM': EDIM,
                'OPTIMIZER_NAME': OPTIMIZER_NAME,
                'LR': LR
            }
        )

# %%
USER = 0

preds = list(model.pred_top_k(torch.tensor([USER]), 10)[1][0].numpy())
df[(df['user_index'] == USER) & (df['node_index'].isin(user2seen[USER]))]['names'].tolist()

# %%
[node2name[index2node[i]] for i in preds]

# %%
K = 100

test_users = df_test['user_index'].unique()


preds = model.pred_top_k(torch.tensor(test_users), K)[1].numpy()
df_preds = pd.DataFrame({'node_index': list(preds), 'user_index': test_users, 'rank': [[j for j in range(0, K)]for i in range(len(preds))]})

df_preds = df_preds.explode(['node_index', 'rank']).merge(
    df_test[['user_index', 'node_index']].assign(relevant=1).drop_duplicates(),
    on = ['user_index', 'node_index'],
    how='left' ,
)
df_preds['relevant'] = df_preds['relevant'].fillna(0)

# %%
def calc_hitrate(df_preds, K):
    return  df_preds[df_preds['rank']<K].groupby('user_index')['relevant'].max().mean()

def calc_prec(df_preds, K):
    return  (df_preds[df_preds['rank']<K].groupby('user_index')['relevant'].mean()).mean()

hitrate = calc_hitrate(df_preds, K)

hitrate, K

# %%
calc_prec(df_preds, 30)

# %%
df_train['node_index'].max()

# %%
top_popular = df_train[['node_index']].assign(v=1).groupby('node_index').count().reset_index().sort_values(by='v').tail(K)['node_index'].values

# %%
node2name[index2node[top_popular[-1]]]

# %%
df_preds_top_poplular = pd.DataFrame({'node_index': [list(top_popular) for i in test_users], 'user_index': test_users, 'rank': [[j for j in range(0, K)]for i in range(len(test_users))]})


df_preds_top_poplular = df_preds_top_poplular.explode(
    ['node_index', 'rank']
).merge(
    df_test[['user_index', 'node_index']].assign(relevant=1).drop_duplicates(),
    on = ['user_index', 'node_index'],
    how='left' ,
)
df_preds_top_poplular['relevant'] = df_preds_top_poplular['relevant'].fillna(0)

calc_hitrate(df_preds_top_poplular, K)

# %%
calc_prec(df_preds_top_poplular, 30)

# %% [markdown]
# # Search best batch_size, edim, num_negatives, lr, Optimizer

# %%
mlflow.set_tracking_uri('http://84.201.128.89:90/')
mlflow.set_experiment('homework-msshelestov')
# Out:
# 2024/06/18 11:30:29 INFO mlflow.tracking.fluent: Experiment with name 'homework-msshelestov' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/39', creation_time=1718710229128, experiment_id='39', last_update_time=1718710229128, lifecycle_stage='active', name='homework-msshelestov', tags={}>

# %%
def calc_hitrate(df_preds: pd.DataFrame, K: int = 30) -> float:
    return  df_preds[df_preds['rank'] < K].groupby('user_index')['relevant'].max().mean()


def calc_prec(df_preds: pd.DataFrame, K: int = 30) -> float:
    return  (df_preds[df_preds['rank'] < K].groupby('user_index')['relevant'].mean()).mean()


def calculate_metrics(model: torch.nn.Module, K: int = 30) -> float:
    test_users = df_test['user_index'].unique()
    preds = model.pred_top_k(torch.tensor(test_users), K)[1].numpy()
    df_preds = pd.DataFrame({'node_index': list(preds), 'user_index': test_users, 'rank': [[j for j in range(0, K)]for i in range(len(preds))]})
    df_preds = df_preds.explode(['node_index', 'rank']).merge(
        df_test[['user_index', 'node_index']].assign(relevant=1).drop_duplicates(),
        on = ['user_index', 'node_index'],
        how='left' ,
    )
    df_preds['relevant'] = df_preds['relevant'].fillna(0)
    return calc_hitrate(df_preds), calc_prec(df_preds)


def train_model(model: torch.nn.Module, optimizer: torch.optim, dataloader: DataLoader, epoch: int) -> torch.nn.Module:
    for i in range(epoch):
        losses = []
        for i in dataloader:
            users, items, labels = i
            optimizer.zero_grad()
            logits = model(users, items)
            loss = torch.nn.functional.binary_cross_entropy_with_logits(
                logits, labels
            )
            loss.backward()
            optimizer.step()
            losses.append(loss.item())
    return model


def get_optimizer(model, optimizer: str, lr: int) -> torch.optim:
    if optimizer == 'adam':
        return torch.optim.Adam(model.parameters(), lr)
    elif optimizer == 'adamw':
        return torch.optim.AdamW(model.parameters(), lr)
    elif optimizer == 'rmsprop':
        return torch.optim.RMSprop(model.parameters(), lr)
    elif optimizer == 'adadelta':
        return torch.optim.Adadelta(model.parameters(), lr)
    return torch.optim.SGD(model.parameters(), lr, momentum=0.1)


def objective(trial) -> float:
    EPOCH = trial.suggest_int('EPOCH', 5, 15)
    BATCH_SIZE = trial.suggest_int('BATCH_SIZE', 64, 50000)
    NUM_NEGATIVES = trial.suggest_int('NUM_NEGATIVES', 1, 20)
    EDIM = trial.suggest_int('EDIM', 32, 512)
    OPTIMIZER_NAME = trial.suggest_categorical('optimizer', ['adam', 'adamw', 'rmsprop', 'adadelta', 'sgd'])
    LR = trial.suggest_float('LR', 1e-4, 5e-2)

    train_dataset = RecDataset(df_train['user_index'].values, df_train['node_index'], user2seen)
    dataloader = DataLoader(train_dataset, shuffle=True, num_workers=0, batch_size=BATCH_SIZE,
                            collate_fn=lambda x: collate_fn(x, NUM_NEGATIVES, max(df['node_index'].values)))
    model = LatentFactorModel(EDIM, user_indes, node_indes)
    optimizer = get_optimizer(model, OPTIMIZER_NAME, LR)

    model = train_model(model, optimizer, dataloader, EPOCH)
    hitrate, precision = calculate_metrics(model)

    with mlflow.start_run(run_name=f'{trial.number}-trial optuna tuning'):
        mlflow.log_metrics(
            {
                'hitrate-30': hitrate,
                'precision-30': precision,
            }
        )
        mlflow.log_params(
            {
                'BATCH_SIZE': BATCH_SIZE,
                'EPOCH': EPOCH,
                'NUM_NEGATIVES': NUM_NEGATIVES,
                'EDIM': EDIM,
                'OPTIMIZER_NAME': OPTIMIZER_NAME,
                'LR': LR
            }
        )
    return precision


sampler = optuna.samplers.TPESampler(seed=42)
study = optuna.create_study(
    study_name='Optimize_LatentModel',
    sampler=sampler,
    direction='maximize',
)
study.optimize(objective, n_trials=75)
# Out:
# [I 2024-06-18 11:37:03,580] A new study created in memory with name: Optimize_LatentModel
# [I 2024-06-18 11:39:05,178] Trial 0 finished with value: 0.0010494752623688155 and parameters: {'EPOCH': 9, 'BATCH_SIZE': 47539, 'NUM_NEGATIVES': 15, 'EDIM': 319, 'optimizer': 'adadelta', 'LR': 0.035432821632022674}. Best is trial 0 with value: 0.0010494752623688155.
# [I 2024-06-18 11:39:58,760] Trial 1 finished with value: 0.0014492753623188406 and parameters: {'EPOCH': 5, 'BATCH_SIZE': 48498, 'NUM_NEGATIVES': 17, 'EDIM': 134, 'optimizer': 'adadelta', 'LR': 0.01463233409588229}. Best is trial 1 with value: 0.0014492753623188406.
# [I 2024-06-18 11:41:19,657] Trial 2 finished with value: 0.0016491754122938533 and parameters: {'EPOCH': 11, 'BATCH_SIZE': 7029, 'NUM_NEGATIVES': 6, 'EDIM': 208, 'optimizer': 'adamw', 'LR': 0.002417875594727886}. Best is trial 2 with value: 0.0016491754122938533.
# [I 2024-06-18 11:42:30,168] Trial 3 finished with value: 0.022038980509745128 and parameters: {'EPOCH': 11, 'BATCH_SIZE': 8579, 'NUM_NEGATIVES': 2, 'EDIM': 488, 'optimizer': 'adam', 'LR': 0.022063609437606106}. Best is trial 3 with value: 0.022038980509745128.
# [I 2024-06-18 11:43:04,808] Trial 4 finished with value: 0.001549225387306347 and parameters: {'EPOCH': 6, 'BATCH_SIZE': 24791, 'NUM_NEGATIVES': 1, 'EDIM': 469, 'optimizer': 'adamw', 'LR': 0.009324237330723798}. Best is trial 3 with value: 0.022038980509745128.
# [I 2024-06-18 11:48:13,402] Trial 5 finished with value: 0.030034982508745624 and parameters: {'EPOCH': 15, 'BATCH_SIZE': 38771, 'NUM_NEGATIVES': 19, 'EDIM': 462, 'optimizer': 'adamw', 'LR': 0.01633398350508689}. Best is trial 5 with value: 0.030034982508745624.
# [I 2024-06-18 11:50:07,650] Trial 6 finished with value: 0.001549225387306347 and parameters: {'EPOCH': 9, 'BATCH_SIZE': 13614, 'NUM_NEGATIVES': 17, 'EDIM': 203, 'optimizer': 'adadelta', 'LR': 0.049345658136365815}. Best is trial 5 with value: 0.030034982508745624.
# [I 2024-06-18 11:51:15,773] Trial 7 finished with value: 0.0033483258370814594 and parameters: {'EPOCH': 13, 'BATCH_SIZE': 9987, 'NUM_NEGATIVES': 1, 'EDIM': 424, 'optimizer': 'rmsprop', 'LR': 0.005881866070303973}. Best is trial 5 with value: 0.030034982508745624.
# [I 2024-06-18 11:52:42,904] Trial 8 finished with value: 0.0005997001499250375 and parameters: {'EPOCH': 14, 'BATCH_SIZE': 31189, 'NUM_NEGATIVES': 7, 'EDIM': 62, 'optimizer': 'sgd', 'LR': 0.02366352476558127}. Best is trial 5 with value: 0.030034982508745624.
# [I 2024-06-18 11:54:15,563] Trial 9 finished with value: 0.0019490254872563722 and parameters: {'EPOCH': 6, 'BATCH_SIZE': 35681, 'NUM_NEGATIVES': 16, 'EDIM': 301, 'optimizer': 'adam', 'LR': 0.005483782206965893}. Best is trial 5 with value: 0.030034982508745624.
# [I 2024-06-18 11:58:58,828] Trial 10 finished with value: 0.042928535732133934 and parameters: {'EPOCH': 15, 'BATCH_SIZE': 38185, 'NUM_NEGATIVES': 20, 'EDIM': 376, 'optimizer': 'adamw', 'LR': 0.03454332897110034}. Best is trial 10 with value: 0.042928535732133934.
# [I 2024-06-18 12:04:10,184] Trial 11 finished with value: 0.04342828585707146 and parameters: {'EPOCH': 15, 'BATCH_SIZE': 40090, 'NUM_NEGATIVES': 20, 'EDIM': 387, 'optimizer': 'adamw', 'LR': 0.03540652698335694}. Best is trial 11 with value: 0.04342828585707146.
# [I 2024-06-18 12:07:00,648] Trial 12 finished with value: 0.04192903548225887 and parameters: {'EPOCH': 13, 'BATCH_SIZE': 23531, 'NUM_NEGATIVES': 12, 'EDIM': 373, 'optimizer': 'adamw', 'LR': 0.03532793031651621}. Best is trial 11 with value: 0.04342828585707146.
# [I 2024-06-18 12:11:42,774] Trial 13 finished with value: 0.04302848575712143 and parameters: {'EPOCH': 15, 'BATCH_SIZE': 40816, 'NUM_NEGATIVES': 20, 'EDIM': 367, 'optimizer': 'adamw', 'LR': 0.03608393703443325}. Best is trial 11 with value: 0.04342828585707146.
# [I 2024-06-18 12:14:48,492] Trial 14 finished with value: 0.0013493253373313343 and parameters: {'EPOCH': 13, 'BATCH_SIZE': 43753, 'NUM_NEGATIVES': 13, 'EDIM': 374, 'optimizer': 'sgd', 'LR': 0.044629741069051695}. Best is trial 11 with value: 0.04342828585707146.
# [I 2024-06-18 12:18:39,616] Trial 15 finished with value: 0.04762618690654673 and parameters: {'EPOCH': 15, 'BATCH_SIZE': 30214, 'NUM_NEGATIVES': 20, 'EDIM': 263, 'optimizer': 'rmsprop', 'LR': 0.04184480575187193}. Best is trial 15 with value: 0.04762618690654673.
# [I 2024-06-18 12:20:29,730] Trial 16 finished with value: 0.04702648675662169 and parameters: {'EPOCH': 12, 'BATCH_SIZE': 29975, 'NUM_NEGATIVES': 9, 'EDIM': 233, 'optimizer': 'rmsprop', 'LR': 0.0442825136046358}. Best is trial 15 with value: 0.04762618690654673.
# [I 2024-06-18 12:22:01,814] Trial 17 finished with value: 0.047176411794102945 and parameters: {'EPOCH': 11, 'BATCH_SIZE': 19288, 'NUM_NEGATIVES': 8, 'EDIM': 236, 'optimizer': 'rmsprop', 'LR': 0.041551411605622916}. Best is trial 15 with value: 0.04762618690654673.
# [I 2024-06-18 12:22:55,054] Trial 18 finished with value: 0.04492753623188406 and parameters: {'EPOCH': 9, 'BATCH_SIZE': 18120, 'NUM_NEGATIVES': 5, 'EDIM': 128, 'optimizer': 'rmsprop', 'LR': 0.02916729302397726}. Best is trial 15 with value: 0.04762618690654673.
# [I 2024-06-18 12:24:06,527] Trial 19 finished with value: 0.0409295352323838 and parameters: {'EPOCH': 8, 'BATCH_SIZE': 1108, 'NUM_NEGATIVES': 9, 'EDIM': 254, 'optimizer': 'rmsprop', 'LR': 0.042996528772258014}. Best is trial 15 with value: 0.04762618690654673.
# [I 2024-06-18 12:25:46,649] Trial 20 finished with value: 0.04822588705647176 and parameters: {'EPOCH': 11, 'BATCH_SIZE': 19477, 'NUM_NEGATIVES': 11, 'EDIM': 156, 'optimizer': 'rmsprop', 'LR': 0.028450823680539875}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:27:23,071] Trial 21 finished with value: 0.0472263868065967 and parameters: {'EPOCH': 11, 'BATCH_SIZE': 18253, 'NUM_NEGATIVES': 11, 'EDIM': 162, 'optimizer': 'rmsprop', 'LR': 0.02872961246709831}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:28:56,808] Trial 22 finished with value: 0.04642678660669665 and parameters: {'EPOCH': 10, 'BATCH_SIZE': 29554, 'NUM_NEGATIVES': 12, 'EDIM': 164, 'optimizer': 'rmsprop', 'LR': 0.029616731782686714}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:29:56,509] Trial 23 finished with value: 0.04372813593203398 and parameters: {'EPOCH': 12, 'BATCH_SIZE': 18126, 'NUM_NEGATIVES': 4, 'EDIM': 43, 'optimizer': 'rmsprop', 'LR': 0.030378562250419884}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:31:01,067] Trial 24 finished with value: 0.038680659670164916 and parameters: {'EPOCH': 8, 'BATCH_SIZE': 21151, 'NUM_NEGATIVES': 11, 'EDIM': 112, 'optimizer': 'rmsprop', 'LR': 0.018150793695994816}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:33:09,003] Trial 25 finished with value: 0.04787606196901549 and parameters: {'EPOCH': 12, 'BATCH_SIZE': 13356, 'NUM_NEGATIVES': 15, 'EDIM': 171, 'optimizer': 'rmsprop', 'LR': 0.025858945232183593}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:35:14,478] Trial 26 finished with value: 0.04757621189405298 and parameters: {'EPOCH': 14, 'BATCH_SIZE': 13944, 'NUM_NEGATIVES': 14, 'EDIM': 86, 'optimizer': 'rmsprop', 'LR': 0.02097053636270435}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:37:45,324] Trial 27 finished with value: 0.0456271864067966 and parameters: {'EPOCH': 12, 'BATCH_SIZE': 1976, 'NUM_NEGATIVES': 18, 'EDIM': 291, 'optimizer': 'rmsprop', 'LR': 0.026133830053047428}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:40:13,949] Trial 28 finished with value: 0.013993003498250875 and parameters: {'EPOCH': 14, 'BATCH_SIZE': 27355, 'NUM_NEGATIVES': 15, 'EDIM': 176, 'optimizer': 'adam', 'LR': 0.012546747127053403}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:42:31,019] Trial 29 finished with value: 0.0010494752623688157 and parameters: {'EPOCH': 10, 'BATCH_SIZE': 33380, 'NUM_NEGATIVES': 16, 'EDIM': 282, 'optimizer': 'sgd', 'LR': 0.038661452817034675}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:43:57,932] Trial 30 finished with value: 0.0012493753123438284 and parameters: {'EPOCH': 8, 'BATCH_SIZE': 12929, 'NUM_NEGATIVES': 14, 'EDIM': 199, 'optimizer': 'adadelta', 'LR': 0.025971358537004673}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:45:54,412] Trial 31 finished with value: 0.04472763618190904 and parameters: {'EPOCH': 13, 'BATCH_SIZE': 13773, 'NUM_NEGATIVES': 14, 'EDIM': 92, 'optimizer': 'rmsprop', 'LR': 0.02075369147208291}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:47:51,236] Trial 32 finished with value: 0.042328835582208894 and parameters: {'EPOCH': 14, 'BATCH_SIZE': 23136, 'NUM_NEGATIVES': 14, 'EDIM': 73, 'optimizer': 'rmsprop', 'LR': 0.018868549699952775}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:50:23,387] Trial 33 finished with value: 0.0480759620189905 and parameters: {'EPOCH': 14, 'BATCH_SIZE': 4677, 'NUM_NEGATIVES': 17, 'EDIM': 141, 'optimizer': 'rmsprop', 'LR': 0.03236183783881783}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:53:54,747] Trial 34 finished with value: 0.04632683658170914 and parameters: {'EPOCH': 12, 'BATCH_SIZE': 4017, 'NUM_NEGATIVES': 18, 'EDIM': 334, 'optimizer': 'rmsprop', 'LR': 0.032036579737151835}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:56:36,351] Trial 35 finished with value: 0.0015492253873063467 and parameters: {'EPOCH': 14, 'BATCH_SIZE': 5080, 'NUM_NEGATIVES': 18, 'EDIM': 140, 'optimizer': 'adadelta', 'LR': 0.03975568961930066}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 12:58:47,875] Trial 36 finished with value: 0.04762618690654673 and parameters: {'EPOCH': 11, 'BATCH_SIZE': 9367, 'NUM_NEGATIVES': 16, 'EDIM': 184, 'optimizer': 'rmsprop', 'LR': 0.047315791704006446}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 13:02:07,564] Trial 37 finished with value: 0.04632683658170914 and parameters: {'EPOCH': 15, 'BATCH_SIZE': 7424, 'NUM_NEGATIVES': 17, 'EDIM': 236, 'optimizer': 'adam', 'LR': 0.02626349976979665}. Best is trial 20 with value: 0.04822588705647176.
# [I 2024-06-18 13:04:43,421] Trial 38 finished with value: 0.04887556221889055 and parameters: {'EPOCH': 13, 'BATCH_SIZE': 11454, 'NUM_NEGATIVES': 19, 'EDIM': 146, 'optimizer': 'rmsprop', 'LR': 0.03240999255022217}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:07:15,592] Trial 39 finished with value: 0.04782608695652174 and parameters: {'EPOCH': 13, 'BATCH_SIZE': 15690, 'NUM_NEGATIVES': 19, 'EDIM': 136, 'optimizer': 'rmsprop', 'LR': 0.03223771626260924}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:08:50,241] Trial 40 finished with value: 0.0012493753123438282 and parameters: {'EPOCH': 12, 'BATCH_SIZE': 11063, 'NUM_NEGATIVES': 10, 'EDIM': 120, 'optimizer': 'adadelta', 'LR': 0.024187186598142556}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:11:25,065] Trial 41 finished with value: 0.047776111944027984 and parameters: {'EPOCH': 13, 'BATCH_SIZE': 15658, 'NUM_NEGATIVES': 19, 'EDIM': 144, 'optimizer': 'rmsprop', 'LR': 0.03285912550794912}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:13:23,445] Trial 42 finished with value: 0.04877561219390304 and parameters: {'EPOCH': 11, 'BATCH_SIZE': 11168, 'NUM_NEGATIVES': 19, 'EDIM': 104, 'optimizer': 'rmsprop', 'LR': 0.038334753083570115}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:15:05,825] Trial 43 finished with value: 0.04757621189405297 and parameters: {'EPOCH': 10, 'BATCH_SIZE': 5650, 'NUM_NEGATIVES': 17, 'EDIM': 101, 'optimizer': 'rmsprop', 'LR': 0.038074372067618975}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:16:45,337] Trial 44 finished with value: 0.0009995002498750627 and parameters: {'EPOCH': 11, 'BATCH_SIZE': 11275, 'NUM_NEGATIVES': 17, 'EDIM': 58, 'optimizer': 'sgd', 'LR': 0.028043020744795956}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:18:53,966] Trial 45 finished with value: 0.04847576211894052 and parameters: {'EPOCH': 11, 'BATCH_SIZE': 8116, 'NUM_NEGATIVES': 15, 'EDIM': 212, 'optimizer': 'rmsprop', 'LR': 0.036774012499851676}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:20:56,367] Trial 46 finished with value: 0.04637681159420289 and parameters: {'EPOCH': 9, 'BATCH_SIZE': 7355, 'NUM_NEGATIVES': 19, 'EDIM': 214, 'optimizer': 'adam', 'LR': 0.03712222284984741}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:22:48,784] Trial 47 finished with value: 0.04817591204397801 and parameters: {'EPOCH': 10, 'BATCH_SIZE': 3136, 'NUM_NEGATIVES': 18, 'EDIM': 207, 'optimizer': 'rmsprop', 'LR': 0.03400126316024382}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:26:02,846] Trial 48 finished with value: 0.042078960519740125 and parameters: {'EPOCH': 10, 'BATCH_SIZE': 197, 'NUM_NEGATIVES': 18, 'EDIM': 199, 'optimizer': 'rmsprop', 'LR': 0.03431854259812909}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:27:40,279] Trial 49 finished with value: 0.0013493253373313343 and parameters: {'EPOCH': 9, 'BATCH_SIZE': 2804, 'NUM_NEGATIVES': 16, 'EDIM': 218, 'optimizer': 'sgd', 'LR': 0.04024392817022963}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:30:47,425] Trial 50 finished with value: 0.04692653673163418 and parameters: {'EPOCH': 11, 'BATCH_SIZE': 7494, 'NUM_NEGATIVES': 20, 'EDIM': 325, 'optimizer': 'adamw', 'LR': 0.036675738601186086}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:33:00,965] Trial 51 finished with value: 0.04847576211894054 and parameters: {'EPOCH': 11, 'BATCH_SIZE': 4698, 'NUM_NEGATIVES': 19, 'EDIM': 150, 'optimizer': 'rmsprop', 'LR': 0.033185902437560685}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:35:00,729] Trial 52 finished with value: 0.04867566216891554 and parameters: {'EPOCH': 10, 'BATCH_SIZE': 9655, 'NUM_NEGATIVES': 19, 'EDIM': 153, 'optimizer': 'rmsprop', 'LR': 0.03405757800704252}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:37:21,259] Trial 53 finished with value: 0.04817591204397801 and parameters: {'EPOCH': 11, 'BATCH_SIZE': 10843, 'NUM_NEGATIVES': 20, 'EDIM': 156, 'optimizer': 'rmsprop', 'LR': 0.030704148136246296}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:39:22,452] Trial 54 finished with value: 0.04877561219390304 and parameters: {'EPOCH': 11, 'BATCH_SIZE': 16300, 'NUM_NEGATIVES': 19, 'EDIM': 111, 'optimizer': 'rmsprop', 'LR': 0.03578224291602718}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:41:03,346] Trial 55 finished with value: 0.04842578710644677 and parameters: {'EPOCH': 9, 'BATCH_SIZE': 9055, 'NUM_NEGATIVES': 19, 'EDIM': 107, 'optimizer': 'rmsprop', 'LR': 0.046466902221732165}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:41:55,905] Trial 56 finished with value: 0.04257871064467766 and parameters: {'EPOCH': 5, 'BATCH_SIZE': 15935, 'NUM_NEGATIVES': 19, 'EDIM': 80, 'optimizer': 'rmsprop', 'LR': 0.04059972105541055}. Best is trial 38 with value: 0.04887556221889055.
# [I 2024-06-18 13:43:55,413] Trial 57 finished with value: 0.04832583708145927 and parameters: {'EPOCH': 10, 'BATCH_SIZE': 6301, 'NUM_NEGATIVES': 20, 'EDIM': 126, 'optimizer': 'rmsprop', 'LR': 0.035513382298835335}. Best is trial 38 with value: 0.04887556221889055.
# [W 2024-06-18 13:46:14,401] Trial 58 failed with parameters: {'EPOCH': 11, 'BATCH_SIZE': 11983, 'NUM_NEGATIVES': 19, 'EDIM': 189, 'optimizer': 'adamw', 'LR': 0.04271875194734563} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "<ipython-input-41-c838a590dac4>", line 64, in objective
#     model = train_model(model, optimizer, dataloader, EPOCH)
#   File "<ipython-input-41-c838a590dac4>", line 32, in train_model
#     loss.backward()
#   File "/usr/local/lib/python3.10/dist-packages/torch/_tensor.py", line 525, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py", line 267, in backward
#     _engine_run_backward(
#   File "/usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py", line 744, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt
# [W 2024-06-18 13:46:14,403] Trial 58 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-c838a590dac4> in <cell line: 93>()
#      91     direction='maximize',
#      92 )
# ---> 93 study.optimize(objective, n_trials=75)
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     449                 If nested invocation of this method occurs.
#     450         """
# --> 451         _optimize(
#     452             study=self,
#     453             func=func,
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      60     try:
#      61         if n_jobs == 1:
# ---> 62             _optimize_sequential(
#      63                 study,
#      64                 func,
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157
#     158         try:
# --> 159             frozen_trial = _run_trial(study, func, catch)
#     160         finally:
#     161             # The following line mitigates memory problems that can be occurred in some
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     245         and not isinstance(func_err, catch)
#     246     ):
# --> 247         raise func_err
#     248     return frozen_trial
#     249
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     194     with get_heartbeat_thread(trial._trial_id, study._storage):
#     195         try:
# --> 196             value_or_values = func(trial)
#     197         except exceptions.TrialPruned as e:
#     198             # TODO(mamu): Handle multi-objective cases.
#
# <ipython-input-41-c838a590dac4> in objective(trial)
#      62     optimizer = get_optimizer(model, OPTIMIZER_NAME, LR)
#      63
# ---> 64     model = train_model(model, optimizer, dataloader, EPOCH)
#      65     hitrate, precision = calculate_metrics(model)
#      66
#
# <ipython-input-41-c838a590dac4> in train_model(model, optimizer, dataloader, epoch)
#      30                 logits, labels
#      31             )
# ---> 32             loss.backward()
#      33             optimizer.step()
#      34             losses.append(loss.item())
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     523                 inputs=inputs,
#     524             )
# --> 525         torch.autograd.backward(
#     526             self, gradient, retain_graph, create_graph, inputs=inputs
#     527         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     265     # some Python versions print out the first line of a multi-line function
#     266     # calls in the traceback and some print out the last line
# --> 267     _engine_run_backward(
#     268         tensors,
#     269         grad_tensors_,
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     742         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743     try:
# --> 744         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745             t_outputs, *args, **kwargs
#     746         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
print(study.best_params)
study.best_trial
# Out:
# {'EPOCH': 13, 'BATCH_SIZE': 11454, 'NUM_NEGATIVES': 19, 'EDIM': 146, 'optimizer': 'rmsprop', 'LR': 0.03240999255022217}
# FrozenTrial(number=38, state=TrialState.COMPLETE, values=[0.04887556221889055], datetime_start=datetime.datetime(2024, 6, 18, 13, 2, 7, 565805), datetime_complete=datetime.datetime(2024, 6, 18, 13, 4, 43, 420939), params={'EPOCH': 13, 'BATCH_SIZE': 11454, 'NUM_NEGATIVES': 19, 'EDIM': 146, 'optimizer': 'rmsprop', 'LR': 0.03240999255022217}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'EPOCH': IntDistribution(high=15, log=False, low=5, step=1), 'BATCH_SIZE': IntDistribution(high=50000, log=False, low=64, step=1), 'NUM_NEGATIVES': IntDistribution(high=20, log=False, low=1, step=1), 'EDIM': IntDistribution(high=512, log=False, low=32, step=1), 'optimizer': CategoricalDistribution(choices=('adam', 'adamw', 'rmsprop', 'adadelta', 'sgd')), 'LR': FloatDistribution(high=0.05, log=False, low=0.0001, step=None)}, trial_id=38, value=None)

# %%
EPOCH = 13
BATCH_SIZE = 11454
NUM_NEGATIVES = 19
EDIM = 146
OPTIMIZER_NAME = 'rmsprop'
LR = 0.03240999255022217
train_dataset = RecDataset(df_train['user_index'].values, df_train['node_index'], user2seen)
dataloader = DataLoader(train_dataset, shuffle=True, num_workers=0, batch_size=BATCH_SIZE,
                        collate_fn=lambda x: collate_fn(x, NUM_NEGATIVES, max(df['node_index'].values)))
model = LatentFactorModel(EDIM, user_indes, node_indes)
optimizer = get_optimizer(model, OPTIMIZER_NAME, LR)
model = train_model(model, optimizer, dataloader, EPOCH)
hitrate, precision = calculate_metrics(model)
hitrate, precision
# Out:
# (0.7451274362818591, 0.04922538730634682)

# %% [markdown]
# # ALS

# %%
def create_csr_matrix_matrix_string(df: pd.DataFrame):
    nodes_count = df.loc[df['is_train'], 'node_index'].nunique()
    train_list = []
    tmp = df.loc[df['is_train'], ['user_index', 'node_index']].groupby('user_index')
    for user_id in df.loc[:, 'user_index'].unique():
        items_string = [0] * nodes_count
        for item in tmp.get_group(user_id).node_index.values:
            items_string[int(item)] = 1
        train_list.append(items_string)
    return train_list


train_data = csr_matrix(create_csr_matrix_matrix_string(df))

# %%
model = implicit.als.AlternatingLeastSquares(factors=16,
                                             iterations=15,
                                             random_state=42
                                             )
model.fit(train_data)
test_users = df_test['user_index'].unique()
preds = model.recommend(test_users, train_data[test_users].tocsr(), N=30)[0]
df_preds = pd.DataFrame({'node_index': list(preds), 'user_index': test_users, 'rank': [[j for j in range(30)]for i in range(len(preds))]})
df_preds = df_preds.explode(['node_index', 'rank']).merge(
    df_test[['user_index', 'node_index']].assign(relevant=1).drop_duplicates(),
    on = ['user_index', 'node_index'],
    how='left'
)
df_preds['relevant'] = df_preds['relevant'].fillna(0)
hitrate = calc_hitrate(df_preds, 30)
prec = calc_prec(df_preds, 30)
hitrate, prec

# %%
with mlflow.start_run(run_name='ALS'):
        mlflow.log_metrics(
            {
                'hitrate-30': hitrate,
                'precision-30': prec,
            }
        )
        mlflow.log_params(
            {
                'factors': model.factors,
                'iterations': model.iterations,
                'random_state': 42,
            }
        )
